# %%
# Importing the necessary libraries
import tensorflow as tf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from keras.models import Model
from keras.applications.resnet import ResNet101
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Dense, GlobalAveragePooling2D, Dropout
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Loading the train data csv file into the workspace
train = pd.read_csv('/content/drive/MyDrive/Diabetic Retinopathy/APTOS 2019/train.csv')

# %%
# Visualizing the dataset
print('Number of train samples: ', train.shape[0])
print(train.head())

f, ax = plt.subplots(figsize=(8, 8))
ax = sns.countplot(x="diagnosis", data=train)
ax.bar_label(ax.containers[0])
sns.despine()
plt.show()
# Out:
# Number of train samples:  3662
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
# Setting the model parameters
batch_size = 10
epochs = 30
initial_epochs = 3
LR = 0.0001
initial_LR = 0.001
h = 700
w = 700
channels = 3
TOTAL_CLASSES = train['diagnosis'].nunique()
Early_Stopping_PATIENCE = 5
Reduce_LR_PATIENCE = 3
DECAY_DROP = 0.5

# %%
# Mapping the images stored in the folder to the CSV file
train["id_code"] = train["id_code"].apply(lambda x: x + ".png")
train['diagnosis'] = train['diagnosis'].astype('str')
train.head()
# Out:
#             id_code diagnosis
# 0  000c1434d8d7.png         2
# 1  001639a390f0.png         4
# 2  0024cdab0c1e.png         1
# 3  002c21358ce6.png         0
# 4  005b95c28852.png         0

# %%
# Loading the train and validation dataset
train_datagen=ImageDataGenerator(rescale=1./255, 
                                 validation_split=0.2,
                                 rotation_range = 30,
                                 width_shift_range = 0.2,
                                 zoom_range = 0.2,
                                 shear_range = 0.2,
                                 horizontal_flip=True)


train_generator=train_datagen.flow_from_dataframe(dataframe=train,
                                                  directory="/content/drive/MyDrive/Diabetic Retinopathy/APTOS 2019/train/",
                                                  x_col="id_code",
                                                  y_col="diagnosis",
                                                  batch_size=batch_size,
                                                  class_mode="categorical",
                                                  target_size=(h, w),
                                                  subset='training')

valid_generator=train_datagen.flow_from_dataframe(dataframe=train,
                                                  directory="/content/drive/MyDrive/Diabetic Retinopathy/APTOS 2019/train/",
                                                  x_col="id_code",
                                                  y_col="diagnosis",
                                                  batch_size=batch_size,
                                                  class_mode="categorical",    
                                                  target_size=(h, w),
                                                  subset='validation')
# Out:
# Found 2930 validated image filenames belonging to 5 classes.
# Found 732 validated image filenames belonging to 5 classes.

# %%
# Create the fully connected of the Keras pre-trained model
def create_model(input_shape, n_out):
    input_tensor = Input(shape=input_shape)
    base_model = ResNet101(weights='imagenet', 
                          include_top=False,
                          input_tensor=input_tensor)

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dropout(0.5)(x)
    x = Dense(2048, activation='relu')(x)
    x = Dropout(0.5)(x)
    final_output = Dense(n_out, activation='softmax', name='final_output')(x)
    model = Model(input_tensor, final_output)  
    return model

model = create_model(input_shape=(h, w, channels), n_out=TOTAL_CLASSES)

for layer in model.layers:
    layer.trainable = False

for i in range(-5, 0):
    model.layers[i].trainable = True

for l in model.layers:
    print(l.name, l.trainable)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171450368/171446536 [==============================] - 1s 0us/step
# 171458560/171446536 [==============================] - 1s 0us/step
# input_1 False
# conv1_pad False
# conv1_conv False
# conv1_bn False
# conv1_relu False
# pool1_pad False
# pool1_pool False
# conv2_block1_1_conv False
# conv2_block1_1_bn False
# conv2_block1_1_relu False
# conv2_block1_2_conv False
# conv2_block1_2_bn False
# conv2_block1_2_relu False
# conv2_block1_0_conv False
# conv2_block1_3_conv False
# conv2_block1_0_bn False
# conv2_block1_3_bn False
# conv2_block1_add False
# conv2_block1_out False
# conv2_block2_1_conv False
# conv2_block2_1_bn False
# conv2_block2_1_relu False
# conv2_block2_2_conv False
# conv2_block2_2_bn False
# conv2_block2_2_relu False
# conv2_block2_3_conv False
# conv2_block2_3_bn False
# conv2_block2_add False
# conv2_block2_out False
# conv2_block3_1_conv False
# conv2_block3_1_bn False
# conv2_block3_1_relu False
# conv2_block3_2_conv False
# conv2_block3_2_bn False
# conv2_block3_2_relu False
# conv2_block3_3_conv False
# conv2_block3_3_bn False
# conv2_block3_add False
# conv2_block3_out False
# conv3_block1_1_conv False
# conv3_block1_1_bn False
# conv3_block1_1_relu False
# conv3_block1_2_conv False
# conv3_block1_2_bn False
# conv3_block1_2_relu False
# conv3_block1_0_conv False
# conv3_block1_3_conv False
# conv3_block1_0_bn False
# conv3_block1_3_bn False
# conv3_block1_add False
# conv3_block1_out False
# conv3_block2_1_conv False
# conv3_block2_1_bn False
# conv3_block2_1_relu False
# conv3_block2_2_conv False
# conv3_block2_2_bn False
# conv3_block2_2_relu False
# conv3_block2_3_conv False
# conv3_block2_3_bn False
# conv3_block2_add False
# conv3_block2_out False
# conv3_block3_1_conv False
# conv3_block3_1_bn False
# conv3_block3_1_relu False
# conv3_block3_2_conv False
# conv3_block3_2_bn False
# conv3_block3_2_relu False
# conv3_block3_3_conv False
# conv3_block3_3_bn False
# conv3_block3_add False
# conv3_block3_out False
# conv3_block4_1_conv False
# conv3_block4_1_bn False
# conv3_block4_1_relu False
# conv3_block4_2_conv False
# conv3_block4_2_bn False
# conv3_block4_2_relu False
# conv3_block4_3_conv False
# conv3_block4_3_bn False
# conv3_block4_add False
# conv3_block4_out False
# conv4_block1_1_conv False
# conv4_block1_1_bn False
# conv4_block1_1_relu False
# conv4_block1_2_conv False
# conv4_block1_2_bn False
# conv4_block1_2_relu False
# conv4_block1_0_conv False
# conv4_block1_3_conv False
# conv4_block1_0_bn False
# conv4_block1_3_bn False
# conv4_block1_add False
# conv4_block1_out False
# conv4_block2_1_conv False
# conv4_block2_1_bn False
# conv4_block2_1_relu False
# conv4_block2_2_conv False
# conv4_block2_2_bn False
# conv4_block2_2_relu False
# conv4_block2_3_conv False
# conv4_block2_3_bn False
# conv4_block2_add False
# conv4_block2_out False
# conv4_block3_1_conv False
# conv4_block3_1_bn False
# conv4_block3_1_relu False
# conv4_block3_2_conv False
# conv4_block3_2_bn False
# conv4_block3_2_relu False
# conv4_block3_3_conv False
# conv4_block3_3_bn False
# conv4_block3_add False
# conv4_block3_out False
# conv4_block4_1_conv False
# conv4_block4_1_bn False
# conv4_block4_1_relu False
# conv4_block4_2_conv False
# conv4_block4_2_bn False
# conv4_block4_2_relu False
# conv4_block4_3_conv False
# conv4_block4_3_bn False
# conv4_block4_add False
# conv4_block4_out False
# conv4_block5_1_conv False
# conv4_block5_1_bn False
# conv4_block5_1_relu False
# conv4_block5_2_conv False
# conv4_block5_2_bn False
# conv4_block5_2_relu False
# conv4_block5_3_conv False
# conv4_block5_3_bn False
# conv4_block5_add False
# conv4_block5_out False
# conv4_block6_1_conv False
# conv4_block6_1_bn False
# conv4_block6_1_relu False
# conv4_block6_2_conv False
# conv4_block6_2_bn False
# conv4_block6_2_relu False
# conv4_block6_3_conv False
# conv4_block6_3_bn False
# conv4_block6_add False
# conv4_block6_out False
# conv4_block7_1_conv False
# conv4_block7_1_bn False
# conv4_block7_1_relu False
# conv4_block7_2_conv False
# conv4_block7_2_bn False
# conv4_block7_2_relu False
# conv4_block7_3_conv False
# conv4_block7_3_bn False
# conv4_block7_add False
# conv4_block7_out False
# conv4_block8_1_conv False
# conv4_block8_1_bn False
# conv4_block8_1_relu False
# conv4_block8_2_conv False
# conv4_block8_2_bn False
# conv4_block8_2_relu False
# conv4_block8_3_conv False
# conv4_block8_3_bn False
# conv4_block8_add False
# conv4_block8_out False
# conv4_block9_1_conv False
# conv4_block9_1_bn False
# conv4_block9_1_relu False
# conv4_block9_2_conv False
# conv4_block9_2_bn False
# conv4_block9_2_relu False
# conv4_block9_3_conv False
# conv4_block9_3_bn False
# conv4_block9_add False
# conv4_block9_out False
# conv4_block10_1_conv False
# conv4_block10_1_bn False
# conv4_block10_1_relu False
# conv4_block10_2_conv False
# conv4_block10_2_bn False
# conv4_block10_2_relu False
# conv4_block10_3_conv False
# conv4_block10_3_bn False
# conv4_block10_add False
# conv4_block10_out False
# conv4_block11_1_conv False
# conv4_block11_1_bn False
# conv4_block11_1_relu False
# conv4_block11_2_conv False
# conv4_block11_2_bn False
# conv4_block11_2_relu False
# conv4_block11_3_conv False
# conv4_block11_3_bn False
# conv4_block11_add False
# conv4_block11_out False
# conv4_block12_1_conv False
# conv4_block12_1_bn False
# conv4_block12_1_relu False
# conv4_block12_2_conv False
# conv4_block12_2_bn False
# conv4_block12_2_relu False
# conv4_block12_3_conv False
# conv4_block12_3_bn False
# conv4_block12_add False
# conv4_block12_out False
# conv4_block13_1_conv False
# conv4_block13_1_bn False
# conv4_block13_1_relu False
# conv4_block13_2_conv False
# conv4_block13_2_bn False
# conv4_block13_2_relu False
# conv4_block13_3_conv False
# conv4_block13_3_bn False
# conv4_block13_add False
# conv4_block13_out False
# conv4_block14_1_conv False
# conv4_block14_1_bn False
# conv4_block14_1_relu False
# conv4_block14_2_conv False
# conv4_block14_2_bn False
# conv4_block14_2_relu False
# conv4_block14_3_conv False
# conv4_block14_3_bn False
# conv4_block14_add False
# conv4_block14_out False
# conv4_block15_1_conv False
# conv4_block15_1_bn False
# conv4_block15_1_relu False
# conv4_block15_2_conv False
# conv4_block15_2_bn False
# conv4_block15_2_relu False
# conv4_block15_3_conv False
# conv4_block15_3_bn False
# conv4_block15_add False
# conv4_block15_out False
# conv4_block16_1_conv False
# conv4_block16_1_bn False
# conv4_block16_1_relu False
# conv4_block16_2_conv False
# conv4_block16_2_bn False
# conv4_block16_2_relu False
# conv4_block16_3_conv False
# conv4_block16_3_bn False
# conv4_block16_add False
# conv4_block16_out False
# conv4_block17_1_conv False
# conv4_block17_1_bn False
# conv4_block17_1_relu False
# conv4_block17_2_conv False
# conv4_block17_2_bn False
# conv4_block17_2_relu False
# conv4_block17_3_conv False
# conv4_block17_3_bn False
# conv4_block17_add False
# conv4_block17_out False
# conv4_block18_1_conv False
# conv4_block18_1_bn False
# conv4_block18_1_relu False
# conv4_block18_2_conv False
# conv4_block18_2_bn False
# conv4_block18_2_relu False
# conv4_block18_3_conv False
# conv4_block18_3_bn False
# conv4_block18_add False
# conv4_block18_out False
# conv4_block19_1_conv False
# conv4_block19_1_bn False
# conv4_block19_1_relu False
# conv4_block19_2_conv False
# conv4_block19_2_bn False
# conv4_block19_2_relu False
# conv4_block19_3_conv False
# conv4_block19_3_bn False
# conv4_block19_add False
# conv4_block19_out False
# conv4_block20_1_conv False
# conv4_block20_1_bn False
# conv4_block20_1_relu False
# conv4_block20_2_conv False
# conv4_block20_2_bn False
# conv4_block20_2_relu False
# conv4_block20_3_conv False
# conv4_block20_3_bn False
# conv4_block20_add False
# conv4_block20_out False
# conv4_block21_1_conv False
# conv4_block21_1_bn False
# conv4_block21_1_relu False
# conv4_block21_2_conv False
# conv4_block21_2_bn False
# conv4_block21_2_relu False
# conv4_block21_3_conv False
# conv4_block21_3_bn False
# conv4_block21_add False
# conv4_block21_out False
# conv4_block22_1_conv False
# conv4_block22_1_bn False
# conv4_block22_1_relu False
# conv4_block22_2_conv False
# conv4_block22_2_bn False
# conv4_block22_2_relu False
# conv4_block22_3_conv False
# conv4_block22_3_bn False
# conv4_block22_add False
# conv4_block22_out False
# conv4_block23_1_conv False
# conv4_block23_1_bn False
# conv4_block23_1_relu False
# conv4_block23_2_conv False
# conv4_block23_2_bn False
# conv4_block23_2_relu False
# conv4_block23_3_conv False
# conv4_block23_3_bn False
# conv4_block23_add False
# conv4_block23_out False
# conv5_block1_1_conv False
# conv5_block1_1_bn False
# conv5_block1_1_relu False
# conv5_block1_2_conv False
# conv5_block1_2_bn False
# conv5_block1_2_relu False
# conv5_block1_0_conv False
# conv5_block1_3_conv False
# conv5_block1_0_bn False
# conv5_block1_3_bn False
# conv5_block1_add False
# conv5_block1_out False
# conv5_block2_1_conv False
# conv5_block2_1_bn False
# conv5_block2_1_relu False
# conv5_block2_2_conv False
# conv5_block2_2_bn False
# conv5_block2_2_relu False
# conv5_block2_3_conv False
# conv5_block2_3_bn False
# conv5_block2_add False
# conv5_block2_out False
# conv5_block3_1_conv False
# conv5_block3_1_bn False
# conv5_block3_1_relu False
# conv5_block3_2_conv False
# conv5_block3_2_bn False
# conv5_block3_2_relu False
# conv5_block3_3_conv False
# conv5_block3_3_bn False
# conv5_block3_add False
# conv5_block3_out False
# global_average_pooling2d True
# dropout True
# dense True
# dropout_1 True
# final_output True

# %%
# Defining the metrics and parameters
optimizer = optimizers.Adam(lr=initial_LR)
model.compile(optimizer=optimizer, loss="categorical_crossentropy",  metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 700, 700, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 706, 706, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 350, 350, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 350, 350, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 350, 350, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 352, 352, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 175, 175, 64) 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 175, 175, 64) 4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 175, 175, 64) 256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 175, 175, 64) 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 175, 175, 64) 36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 175, 175, 64) 256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 175, 175, 64) 0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 175, 175, 256 16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 175, 175, 256 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 175, 175, 256 1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 175, 175, 256 1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 175, 175, 256 0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 175, 175, 256 0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 175, 175, 64) 16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 175, 175, 64) 256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 175, 175, 64) 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 175, 175, 64) 36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 175, 175, 64) 256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 175, 175, 64) 0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 175, 175, 256 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 175, 175, 256 1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 175, 175, 256 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 175, 175, 256 0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 175, 175, 64) 16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 175, 175, 64) 256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 175, 175, 64) 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 175, 175, 64) 36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 175, 175, 64) 256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 175, 175, 64) 0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 175, 175, 256 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 175, 175, 256 1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 175, 175, 256 0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 175, 175, 256 0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 88, 88, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 88, 88, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 88, 88, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 88, 88, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 88, 88, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 88, 88, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 88, 88, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 88, 88, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 88, 88, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 88, 88, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 88, 88, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 88, 88, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 88, 88, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 88, 88, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 88, 88, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 88, 88, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 88, 88, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 88, 88, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 88, 88, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 88, 88, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 88, 88, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 88, 88, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 88, 88, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 88, 88, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 88, 88, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 88, 88, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 88, 88, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 88, 88, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 88, 88, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 88, 88, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 88, 88, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 88, 88, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 88, 88, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 88, 88, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 44, 44, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 44, 44, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 44, 44, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 44, 44, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 44, 44, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 44, 44, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 44, 44, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 44, 44, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 44, 44, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 44, 44, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 44, 44, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 44, 44, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 44, 44, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 44, 44, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 44, 44, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 44, 44, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 44, 44, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 44, 44, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 44, 44, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 44, 44, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 44, 44, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 44, 44, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 44, 44, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 44, 44, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 44, 44, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 44, 44, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 44, 44, 256)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (Activation (None, 44, 44, 256)  0           conv4_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_add (Add)          (None, 44, 44, 1024) 0           conv4_block6_out[0][0]
#                                                                  conv4_block7_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_out (Activation)   (None, 44, 44, 1024) 0           conv4_block7_add[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block7_out[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 44, 44, 256)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (Activation (None, 44, 44, 256)  0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_add (Add)          (None, 44, 44, 1024) 0           conv4_block7_out[0][0]
#                                                                  conv4_block8_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_out (Activation)   (None, 44, 44, 1024) 0           conv4_block8_add[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 44, 44, 256)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_relu (Activation (None, 44, 44, 256)  0           conv4_block9_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block9_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block9_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_add (Add)          (None, 44, 44, 1024) 0           conv4_block8_out[0][0]
#                                                                  conv4_block9_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_out (Activation)   (None, 44, 44, 1024) 0           conv4_block9_add[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block9_out[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block10_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block10_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block10_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_add (Add)         (None, 44, 44, 1024) 0           conv4_block9_out[0][0]
#                                                                  conv4_block10_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_out (Activation)  (None, 44, 44, 1024) 0           conv4_block10_add[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block10_out[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block11_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block11_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block11_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_add (Add)         (None, 44, 44, 1024) 0           conv4_block10_out[0][0]
#                                                                  conv4_block11_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_out (Activation)  (None, 44, 44, 1024) 0           conv4_block11_add[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block11_out[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block12_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block12_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block12_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_add (Add)         (None, 44, 44, 1024) 0           conv4_block11_out[0][0]
#                                                                  conv4_block12_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_out (Activation)  (None, 44, 44, 1024) 0           conv4_block12_add[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block12_out[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block13_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block13_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block13_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_add (Add)         (None, 44, 44, 1024) 0           conv4_block12_out[0][0]
#                                                                  conv4_block13_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_out (Activation)  (None, 44, 44, 1024) 0           conv4_block13_add[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block13_out[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block14_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block14_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block14_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block14_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block14_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block14_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block14_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block14_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_add (Add)         (None, 44, 44, 1024) 0           conv4_block13_out[0][0]
#                                                                  conv4_block14_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_out (Activation)  (None, 44, 44, 1024) 0           conv4_block14_add[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block14_out[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block15_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block15_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block15_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block15_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block15_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block15_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block15_2_relu[0][0]
# __________________________________________________________________________________________________
# ...
# conv4_block20_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block20_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block20_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block20_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block20_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block20_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block20_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block20_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block20_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block20_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block20_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block20_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block20_add (Add)         (None, 44, 44, 1024) 0           conv4_block19_out[0][0]
#                                                                  conv4_block20_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block20_out (Activation)  (None, 44, 44, 1024) 0           conv4_block20_add[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block20_out[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block21_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block21_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block21_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block21_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block21_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block21_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block21_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_add (Add)         (None, 44, 44, 1024) 0           conv4_block20_out[0][0]
#                                                                  conv4_block21_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_out (Activation)  (None, 44, 44, 1024) 0           conv4_block21_add[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block21_out[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block22_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block22_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block22_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block22_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block22_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block22_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_add (Add)         (None, 44, 44, 1024) 0           conv4_block21_out[0][0]
#                                                                  conv4_block22_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_out (Activation)  (None, 44, 44, 1024) 0           conv4_block22_add[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block22_out[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block23_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block23_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block23_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_add (Add)         (None, 44, 44, 1024) 0           conv4_block22_out[0][0]
#                                                                  conv4_block23_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_out (Activation)  (None, 44, 44, 1024) 0           conv4_block23_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 22, 22, 512)  524800      conv4_block23_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 22, 22, 512)  2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 22, 22, 512)  0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 22, 22, 512)  2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 22, 22, 512)  2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 22, 22, 512)  0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 22, 22, 2048) 2099200     conv4_block23_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 22, 22, 2048) 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 22, 22, 2048) 8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 22, 22, 2048) 8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 22, 22, 2048) 0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 22, 22, 2048) 0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 22, 22, 512)  1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 22, 22, 512)  2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 22, 22, 512)  0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 22, 22, 512)  2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 22, 22, 512)  2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 22, 22, 512)  0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 22, 22, 2048) 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 22, 22, 2048) 8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 22, 22, 2048) 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 22, 22, 2048) 0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 22, 22, 512)  1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 22, 22, 512)  2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 22, 22, 512)  0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 22, 22, 512)  2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 22, 22, 512)  2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 22, 22, 512)  0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 22, 22, 2048) 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 22, 22, 2048) 8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 22, 22, 2048) 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 22, 22, 2048) 0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2048)         4196352     dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 2048)         0           dense[0][0]
# __________________________________________________________________________________________________
# final_output (Dense)            (None, 5)            10245       dropout_1[0][0]
# ==================================================================================================
# Total params: 46,864,773
# Trainable params: 4,206,597
# Non-trainable params: 42,658,176
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
STEPS_PER_EPOCH_TRAIN = train_generator.n//train_generator.batch_size
STEPS_PER_EPOCH_VALID = valid_generator.n//valid_generator.batch_size

# Training the model with frozen convolutional layers
initial = model.fit_generator(generator = train_generator,
                              steps_per_epoch = STEPS_PER_EPOCH_TRAIN,
                              validation_data = valid_generator,
                              validation_steps = STEPS_PER_EPOCH_VALID,
                              epochs = initial_epochs,
                              verbose = 1).history
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/3
# 293/293 [==============================] - 2970s 10s/step - loss: 3.5014 - accuracy: 0.4005 - val_loss: 1.2854 - val_accuracy: 0.4616
# Epoch 2/3
# 293/293 [==============================] - 390s 1s/step - loss: 1.3307 - accuracy: 0.5047 - val_loss: 1.3249 - val_accuracy: 0.5329
# Epoch 3/3
# 293/293 [==============================] - 396s 1s/step - loss: 1.2698 - accuracy: 0.5132 - val_loss: 1.1950 - val_accuracy: 0.5753

# %%
for layer in model.layers:
    layer.trainable = True

# Defining the metrics to stop model from overfitting 
ES = EarlyStopping(monitor = 'val_loss', mode = 'min', 
                   patience = Early_Stopping_PATIENCE, 
                   restore_best_weights = True, verbose=1)

RLROP = ReduceLROnPlateau(monitor = 'val_accuracy', mode = 'min', 
                          patience = Reduce_LR_PATIENCE, 
                          factor = DECAY_DROP, min_lr = 0.000000001, verbose=1)

# Defining the model parameters
callback_list = [ES, RLROP]
optimizer = optimizers.Adam(lr = LR)
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 700, 700, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 706, 706, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 350, 350, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 350, 350, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 350, 350, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 352, 352, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 175, 175, 64) 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 175, 175, 64) 4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 175, 175, 64) 256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 175, 175, 64) 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 175, 175, 64) 36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 175, 175, 64) 256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 175, 175, 64) 0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 175, 175, 256 16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 175, 175, 256 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 175, 175, 256 1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 175, 175, 256 1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 175, 175, 256 0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 175, 175, 256 0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 175, 175, 64) 16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 175, 175, 64) 256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 175, 175, 64) 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 175, 175, 64) 36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 175, 175, 64) 256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 175, 175, 64) 0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 175, 175, 256 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 175, 175, 256 1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 175, 175, 256 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 175, 175, 256 0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 175, 175, 64) 16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 175, 175, 64) 256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 175, 175, 64) 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 175, 175, 64) 36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 175, 175, 64) 256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 175, 175, 64) 0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 175, 175, 256 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 175, 175, 256 1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 175, 175, 256 0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 175, 175, 256 0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 88, 88, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 88, 88, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 88, 88, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 88, 88, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 88, 88, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 88, 88, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 88, 88, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 88, 88, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 88, 88, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 88, 88, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 88, 88, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 88, 88, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 88, 88, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 88, 88, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 88, 88, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 88, 88, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 88, 88, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 88, 88, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 88, 88, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 88, 88, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 88, 88, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 88, 88, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 88, 88, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 88, 88, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 88, 88, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 88, 88, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 88, 88, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 88, 88, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 88, 88, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 88, 88, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 88, 88, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 88, 88, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 88, 88, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 88, 88, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 88, 88, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 44, 44, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 44, 44, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 44, 44, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 44, 44, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 44, 44, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 44, 44, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 44, 44, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 44, 44, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 44, 44, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 44, 44, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 44, 44, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 44, 44, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 44, 44, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 44, 44, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 44, 44, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 44, 44, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 44, 44, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 44, 44, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 44, 44, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 44, 44, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 44, 44, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 44, 44, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 44, 44, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 44, 44, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 44, 44, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 44, 44, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 44, 44, 256)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (Activation (None, 44, 44, 256)  0           conv4_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_add (Add)          (None, 44, 44, 1024) 0           conv4_block6_out[0][0]
#                                                                  conv4_block7_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_out (Activation)   (None, 44, 44, 1024) 0           conv4_block7_add[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block7_out[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 44, 44, 256)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (Activation (None, 44, 44, 256)  0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_add (Add)          (None, 44, 44, 1024) 0           conv4_block7_out[0][0]
#                                                                  conv4_block8_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_out (Activation)   (None, 44, 44, 1024) 0           conv4_block8_add[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 44, 44, 256)  262400      conv4_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 44, 44, 256)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 44, 44, 256)  590080      conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_bn (BatchNormali (None, 44, 44, 256)  1024        conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_relu (Activation (None, 44, 44, 256)  0           conv4_block9_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_conv (Conv2D)    (None, 44, 44, 1024) 263168      conv4_block9_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_bn (BatchNormali (None, 44, 44, 1024) 4096        conv4_block9_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_add (Add)          (None, 44, 44, 1024) 0           conv4_block8_out[0][0]
#                                                                  conv4_block9_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_out (Activation)   (None, 44, 44, 1024) 0           conv4_block9_add[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block9_out[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block10_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block10_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block10_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_add (Add)         (None, 44, 44, 1024) 0           conv4_block9_out[0][0]
#                                                                  conv4_block10_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_out (Activation)  (None, 44, 44, 1024) 0           conv4_block10_add[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block10_out[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block11_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block11_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block11_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_add (Add)         (None, 44, 44, 1024) 0           conv4_block10_out[0][0]
#                                                                  conv4_block11_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_out (Activation)  (None, 44, 44, 1024) 0           conv4_block11_add[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block11_out[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block12_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block12_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block12_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_add (Add)         (None, 44, 44, 1024) 0           conv4_block11_out[0][0]
#                                                                  conv4_block12_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_out (Activation)  (None, 44, 44, 1024) 0           conv4_block12_add[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block12_out[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block13_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block13_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block13_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_add (Add)         (None, 44, 44, 1024) 0           conv4_block12_out[0][0]
#                                                                  conv4_block13_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_out (Activation)  (None, 44, 44, 1024) 0           conv4_block13_add[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block13_out[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block14_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block14_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block14_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block14_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block14_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block14_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block14_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block14_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_add (Add)         (None, 44, 44, 1024) 0           conv4_block13_out[0][0]
#                                                                  conv4_block14_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_out (Activation)  (None, 44, 44, 1024) 0           conv4_block14_add[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block14_out[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block15_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block15_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block15_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block15_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block15_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block15_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block15_2_relu[0][0]
# __________________________________________________________________________________________________
# ...
# conv4_block20_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block20_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block20_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block20_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block20_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block20_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block20_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block20_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block20_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block20_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block20_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block20_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block20_add (Add)         (None, 44, 44, 1024) 0           conv4_block19_out[0][0]
#                                                                  conv4_block20_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block20_out (Activation)  (None, 44, 44, 1024) 0           conv4_block20_add[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block20_out[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block21_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block21_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block21_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block21_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block21_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block21_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block21_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_add (Add)         (None, 44, 44, 1024) 0           conv4_block20_out[0][0]
#                                                                  conv4_block21_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_out (Activation)  (None, 44, 44, 1024) 0           conv4_block21_add[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block21_out[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block22_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block22_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block22_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block22_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block22_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block22_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_add (Add)         (None, 44, 44, 1024) 0           conv4_block21_out[0][0]
#                                                                  conv4_block22_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_out (Activation)  (None, 44, 44, 1024) 0           conv4_block22_add[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_conv (Conv2D)   (None, 44, 44, 256)  262400      conv4_block22_out[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_relu (Activatio (None, 44, 44, 256)  0           conv4_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_conv (Conv2D)   (None, 44, 44, 256)  590080      conv4_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_bn (BatchNormal (None, 44, 44, 256)  1024        conv4_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_relu (Activatio (None, 44, 44, 256)  0           conv4_block23_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_3_conv (Conv2D)   (None, 44, 44, 1024) 263168      conv4_block23_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_3_bn (BatchNormal (None, 44, 44, 1024) 4096        conv4_block23_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_add (Add)         (None, 44, 44, 1024) 0           conv4_block22_out[0][0]
#                                                                  conv4_block23_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_out (Activation)  (None, 44, 44, 1024) 0           conv4_block23_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 22, 22, 512)  524800      conv4_block23_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 22, 22, 512)  2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 22, 22, 512)  0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 22, 22, 512)  2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 22, 22, 512)  2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 22, 22, 512)  0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 22, 22, 2048) 2099200     conv4_block23_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 22, 22, 2048) 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 22, 22, 2048) 8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 22, 22, 2048) 8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 22, 22, 2048) 0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 22, 22, 2048) 0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 22, 22, 512)  1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 22, 22, 512)  2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 22, 22, 512)  0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 22, 22, 512)  2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 22, 22, 512)  2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 22, 22, 512)  0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 22, 22, 2048) 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 22, 22, 2048) 8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 22, 22, 2048) 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 22, 22, 2048) 0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 22, 22, 512)  1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 22, 22, 512)  2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 22, 22, 512)  0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 22, 22, 512)  2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 22, 22, 512)  2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 22, 22, 512)  0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 22, 22, 2048) 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 22, 22, 2048) 8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 22, 22, 2048) 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 22, 22, 2048) 0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2048)         4196352     dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 2048)         0           dense[0][0]
# __________________________________________________________________________________________________
# final_output (Dense)            (None, 5)            10245       dropout_1[0][0]
# ==================================================================================================
# Total params: 46,864,773
# Trainable params: 46,759,429
# Non-trainable params: 105,344
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
# Training the model
finetune = model.fit_generator(generator=train_generator,
                               steps_per_epoch=STEPS_PER_EPOCH_TRAIN,
                               validation_data=valid_generator,
                               validation_steps=STEPS_PER_EPOCH_VALID,
                               epochs=epochs,
                               callbacks=callback_list,
                               verbose=1).history
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 293/293 [==============================] - 426s 1s/step - loss: 0.4228 - accuracy: 0.6775 - val_loss: 0.9274 - val_accuracy: 0.4616
# Epoch 2/30
# 293/293 [==============================] - 393s 1s/step - loss: 0.2175 - accuracy: 0.7761 - val_loss: 2.3920 - val_accuracy: 0.4603
# Epoch 3/30
# 293/293 [==============================] - 392s 1s/step - loss: 0.1956 - accuracy: 0.7769 - val_loss: 0.3874 - val_accuracy: 0.5932
# Epoch 4/30
# 293/293 [==============================] - 393s 1s/step - loss: 0.1746 - accuracy: 0.8133 - val_loss: 0.2003 - val_accuracy: 0.7658
# Epoch 5/30
# 293/293 [==============================] - 394s 1s/step - loss: 0.1732 - accuracy: 0.8142 - val_loss: 0.2661 - val_accuracy: 0.7438
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 6/30
# 293/293 [==============================] - 397s 1s/step - loss: 0.1555 - accuracy: 0.8266 - val_loss: 0.1660 - val_accuracy: 0.8205
# Epoch 7/30
# 293/293 [==============================] - 398s 1s/step - loss: 0.1440 - accuracy: 0.8521 - val_loss: 0.1677 - val_accuracy: 0.8288
# Epoch 8/30
# 293/293 [==============================] - 393s 1s/step - loss: 0.1356 - accuracy: 0.8545 - val_loss: 0.1863 - val_accuracy: 0.8137
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 9/30
# 293/293 [==============================] - 393s 1s/step - loss: 0.1375 - accuracy: 0.8489 - val_loss: 0.1612 - val_accuracy: 0.8370
# Epoch 10/30
# 293/293 [==============================] - 392s 1s/step - loss: 0.1221 - accuracy: 0.8706 - val_loss: 0.1580 - val_accuracy: 0.8315
# Epoch 11/30
# 293/293 [==============================] - 390s 1s/step - loss: 0.1175 - accuracy: 0.8799 - val_loss: 0.1650 - val_accuracy: 0.8178
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 12/30
# 293/293 [==============================] - 391s 1s/step - loss: 0.1102 - accuracy: 0.8842 - val_loss: 0.1634 - val_accuracy: 0.8356
# Epoch 13/30
# 293/293 [==============================] - 393s 1s/step - loss: 0.1077 - accuracy: 0.8943 - val_loss: 0.1590 - val_accuracy: 0.8397
# Epoch 14/30
# 293/293 [==============================] - 389s 1s/step - loss: 0.0959 - accuracy: 0.9049 - val_loss: 0.1675 - val_accuracy: 0.8356
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 15/30
# 293/293 [==============================] - 388s 1s/step - loss: 0.0895 - accuracy: 0.9055 - val_loss: 0.1573 - val_accuracy: 0.8479
# Epoch 16/30
# 293/293 [==============================] - 399s 1s/step - loss: 0.0818 - accuracy: 0.9142 - val_loss: 0.1599 - val_accuracy: 0.8438
# Epoch 17/30
# 293/293 [==============================] - 402s 1s/step - loss: 0.0816 - accuracy: 0.9212 - val_loss: 0.1661 - val_accuracy: 0.8384
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 18/30
# 293/293 [==============================] - 403s 1s/step - loss: 0.0857 - accuracy: 0.9229 - val_loss: 0.1664 - val_accuracy: 0.8397
# Epoch 19/30
# 293/293 [==============================] - 402s 1s/step - loss: 0.0779 - accuracy: 0.9273 - val_loss: 0.1634 - val_accuracy: 0.8384
# Epoch 20/30
# 293/293 [==============================] - 399s 1s/step - loss: 0.0750 - accuracy: 0.9271 - val_loss: 0.1719 - val_accuracy: 0.8370
# Restoring model weights from the end of the best epoch.
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 00020: early stopping

# %%
sns.set_style("whitegrid")
fig, (ax1, ax2) = plt.subplots(2, 1, sharex='col', figsize=(8, 8))

ax1.plot(finetune['loss'], label='Train loss')
ax1.plot(finetune['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(finetune['accuracy'], label='Train Accuracy')
ax2.plot(finetune['val_accuracy'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %%
# Saving the weights file                                          
model.save('/content/drive/MyDrive/Diabetic Retinopathy/APTOS 2019/Models/ResNet101.h5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
